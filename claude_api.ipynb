# %%
# !pip install -q langchain uuid weaviate-client sentence-transformers
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import random
import anthropic
import re
from dotenv import load_dotenv
import os
from langchain.chat_models import ChatAnthropic
from langchain.prompts import ChatPromptTemplate
import json
import uuid
import weaviate
from sentence_transformers import SentenceTransformer
from typing import List

load_dotenv()
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
WEAVIATE_KEY = os.getenv("WEAVIATE_KEY")
WEAVIATE_URL = os.getenv("WEAVIATE_URL")

model = ChatAnthropic(
    model_name="claude-2",
    anthropic_api_key=ANTHROPIC_API_KEY,
    max_tokens_to_sample=2000,
)


def get_patient_record(seen_ids: List) -> dict:
    """Generate a synthetic medical record for a patient using Claude API"""
    if seen_ids and random.randint(1, 10) in [1, 2, 3]:
        patient_id = random.sample(seen_ids, 1)
    else:
        patient_id = str(uuid.uuid4())
        seen_ids.append(patient_id)
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", ""),
            (
                "human",
                """Generate a synthetic medical record for patient {patient_id}. Include patient_id, date, age,
                  sex, symptoms (a list), diagnoses, medications, 
                  vital signs, lab results, allergies, family 
                  history, and social history. Output as a valid JSON without any additional 
                  explanations or 
                  formatting. Any JSON keys should have whitespace replaced with underscores.
                  """,
            ),
        ]
    )
    chain = prompt | model
    record = chain.invoke({"patient_id": patient_id})
    content = record.content
    pattern = r"```json([\w\W]+?)```"
    code_blocks = re.findall(pattern, content, re.DOTALL)
    my_json = json.loads(code_blocks[0].strip("\n"))
    return {"json": my_json, "seen_ids": seen_ids}


def get_patient_records(num_records: int = 10) -> List[dict]:
    """Loop through the num_records and create a list of patient records by calling Claude API"""
    num_records = num_records
    records = []
    seen_ids = []
    while len(records) < num_records:
        try:
            record = get_patient_record(seen_ids)
            print(record)
            records.append(record["json"])
            seen_ids = record["seen_ids"]
        except Exception as e:
            print(f"exception {e}")
    return records


def loop_and_insert(records: object, endpoint: str, collection_name: str) -> None:
    """Insert list of JSON into a weaviate database and embed only the symptoms"""
    client = weaviate.Client(
        auth_client_secret=weaviate.AuthApiKey(api_key=WEAVIATE_KEY),
        url=endpoint,  # e.g. "https://some-endpoint.weaviate.network/",  # Replace with your endpoint
    )
    model = SentenceTransformer("all-MiniLM-L6-v2")
    # Prepare a batch process
    client.batch.configure(batch_size=10)  # Configure batch
    with client.batch as batch:
        # Batch import all Questions
        for record in records:
            patient_id = record["patient_id"]
            symptoms = record["symptoms"]
            date = record["date"]
            try:
                batch.add_data_object(
                    {"patientID" : patient_id, "symptoms" : symptoms, "date" : date, "record": json.dumps(record)},
                    collection_name,
                    vector=model.encode(", ".join(symptoms)),
                )
            except Exception as e:
                print("Error in inserting: ", e)


def filter_individual_patientID(weaviate_url: str, patientID: str) -> dict:
    client = weaviate.Client(
        auth_client_secret=weaviate.AuthApiKey(api_key=WEAVIATE_KEY),
        url=weaviate_url,  # e.g. "https://some-endpoint.weaviate.network/",  # Replace with your endpoint
    )
    filter = {
        "path": ["patientID"],  # Things appears to be a dynamic name?
        "operator": "Equal",
        "valueString": patientID,
    }
    # Construct a GraphQL query with a filter
    # query = {"Get": {"Things": ["*"]}, "Where": filter}
    result = client.query.get("Patient", ["record"]).with_where(filter).do()
    # Extract the matching Things
    filtered_data = result["data"]["Get"]
    return filtered_data


def get_unique_patientIDs(weaviate_url: str) -> List[str]:
    client = weaviate.Client(
        auth_client_secret=weaviate.AuthApiKey(api_key=WEAVIATE_KEY),
        url=weaviate_url,  # e.g. "https://some-endpoint.weaviate.network/",  # Replace with your endpoint
    )
    # query = {"Get": {"Things": ["patientID"]}}
    result = client.query.get("Patient", ["patientID"]).do()
    # Extract the matching Things
    filtered_data = result["data"]["Get"]["Patient"]
    patient_ids = [i["patientID"] for i in filtered_data]
    return list(set(patient_ids))


def create_summary_database(
    endpoint: str, collection_name: str, patient_ids: List, model, doctor_type: str = "General Practicioner (GP)"
) -> None:
    for id in set(patient_ids):
        data = filter_individual_patientID(endpoint, id)
        # Join all the text of the records together into a single string
        id_string = ""
        for record in data:
            joined_text = json.dumps(record)
            id_string += joined_text

        # Use Claude to summarise the record string
        prompt = ChatPromptTemplate.from_messages(
            [
                (
                    "system",
                    f"""You are a medical summariser with experience in summarising complex medical histories for patients
                 into a concise summary that be understood by a medical profressional, in this instance a {doctor_type}""",
                ),
                (
                    "human",
                    """The following is a concatentation of one or more medical records for an individual.
                    Summarise the following concatenated medical record into a single string that captures
                    the variance of the individual concatenated records: {record_string}""",
                ),
            ]
        )
        chain = prompt | model
        summary = chain.invoke({"record_string": id_string}).content

        # Vectorize summary
        model = SentenceTransformer("all-MiniLM-L6-v2")
        vector = model.encode(summary)
        # Create a new object with id, summary, and vector
        new_obj = {"patientID": id, "summary": summary, "vector": vector}
        # Add to new database
        client = weaviate.Client(
        auth_client_secret=weaviate.AuthApiKey(api_key=WEAVIATE_KEY),
        url=WEAVIATE_URL,  # e.g. "https://some-endpoint.weaviate.network/",  # Replace with your endpoint
    )
        client.batch.add_data_object(new_obj, collection_name)
    client.batch.execute()


def search_for_similar_summaries(endpoint: str, patientID: str, num_results: int = 10) -> tuple:
    """Given a patients summary, return a list of similar summaries including their diagnoses and medications. Give a confidence
    score for the probability that the patient has the same diagnosis and medications as the similar patient"""
    # Get the patient summary
    client = weaviate.Client(url=endpoint)
    filter = {
        "path": ["Things", "patientID"],  # Things appears to be a dynamic name?
        "operator": "Equal",
        "valueString": patientID,
    }
    # Construct a GraphQL query with a filter
    query = {"Get": {"Things": ["*"]}, "Where": filter}
    result = client.query(query)
    # Extract the matching Things
    filtered_data = result["data"]["Get"]["Things"]
    patient_summary = filtered_data[0]["summary"]
    patient_vector = filtered_data[0]["vector"]  # Potentially correct up to this point
    # Search for similar summaries
    query = {
        "Aggregate": {
            "Things": [
                {
                    "similarSummaries": {  # Is this mean to be the collection name?
                        "certainty": 0.8,
                        "limit": num_results,
                        "vector": patient_vector,
                    }
                }
            ]
        }
    }
    result = client.query(query)
    # Extract the matching Things
    similar_summaries = result["data"]["Aggregate"]["Things"][0]["similarSummaries"]  # Also need to change this if so
    print("check the format of similar_summaries to see how to call it")
    print(similar_summaries)
    pids = [s["patientID"] for s in similar_summaries["result"]]
    return (pids, patient_summary)


def filter_for_symptoms(
    patientID: str, symptoms: str, endpoint: str, num_results: int, t1_collection_name: str, t2_collection_name: str
) -> tuple:
    """Function that takes patientID, and a list of symptoms and looks up the patient summary based on ID,
    Then calls the search_for_similar_summaries function to return a list of similar summaries and suggested diagnoses/medications
    """
    model = SentenceTransformer("all-MiniLM-L6-v2")
    symptoms_vector = model.encode(symptoms)
    relevant_summary_pids, summary = search_for_similar_summaries(endpoint, patientID, num_results, t2_collection_name)
    print(relevant_summary_pids)
    client = weaviate.Client(url=endpoint)
    response = (
        client.query.get(t1_collection_name, ["symptoms"])
        .with_where({"path": [patientID], "operator": "In", "valueString": relevant_summary_pids})
        .with_near_vector(
            {
                "vector": symptoms_vector,
            }
        )
        .with_limit(10)
        .with_additional(["distance"])
        .do()
    )
    return (response, summary)


def get_final_output(response: tuple) -> dict:
    """Function that takes the response from the filter_for_symptoms function and returns a final output
    with the patientID, symptoms, diagnoses, medications, and distance"""
    final_output = []
    for i in response["data"]["Get"]["Things"]:
        patientID = i["patientID"]
        symptoms = i["symptoms"]
        diagnoses = i["diagnoses"]
        medications = i["medications"]
        distance = i["distance"]
        final_output.append(
            {
                "patientID": patientID,
                "symptoms": symptoms,
                "diagnoses": diagnoses,
                "medications": medications,
                "distance": distance,
            }
        )
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", """"""),
            (
                "human",
                """You will be provided with a list of diagnoses and medications of patients
                 who experienced similar symptoms. Based on how often these occur, provide the most likely 
                 diagnoses and medications. The output should be JSON format, with medications grouped with 
                 the diagnoses they treat. Do not include any explanation or other information in the output 
                 other than the JSON. 
                 <example_output>{"diagnoses": \[{"diagnosis": "treatment"}\]}</example_output>
                <records>"""
                + f"""{final_output}"""
                + """</records>
                Assistant: {"diagnoses":[]}""",
            ),
        ]
    )
    chain = prompt | model
    final_output = chain.invoke().content
    return final_output


def create_natural_language_summary(summary: str, final_output: dict, target_comprehension: str = "non-specialist audiences") -> str:
    prompt = ChatPromptTemplate.from_messages(
        [
            ("system", f"""You are an expert at communicating complex medical topics to {target_comprehension}"""),
            (
                "human",
                f"""Create a summary of an individual's medical history and likely diagnoses and treatments.
                medical history summary: "{summary}"
                likely diagnoses and treatments: {json.dumps(final_output)}.
                If a particular language is specified, translate the summary into that language.""",
            ),
        ]
    )

    chain = prompt | model
    translated_output = chain.invoke().content
    return translated_output
# Out:
# <>:263: DeprecationWarning: invalid escape sequence '\['
# <>:263: DeprecationWarning: invalid escape sequence '\['
# /var/folders/sz/88ypmmqn0jq157npq4hmjtkh0000gp/T/ipykernel_95087/2576509624.py:263: DeprecationWarning: invalid escape sequence '\['
#   """You will be provided with a list of diagnoses and medications of patients

# %%
records = get_patient_records(10)
print(records)
# Out:
# {'json': {'patient_id': 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'date': '2023-02-22', 'age': 35, 'sex': 'male', 'symptoms': ['cough', 'fever', 'fatigue'], 'diagnoses': ['pneumonia', 'hypertension'], 'medications': ['amoxicillin 500mg', 'lisinopril 10mg'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 80, 'temperature': 100.5, 'respiratory_rate': 18}, 'lab_results': {'wbc': 9000, 'hemoglobin': 14.2, 'platelets': 250}, 'allergies': ['penicillin', 'shellfish'], 'family_history': {'diabetes': 'father', 'heart_disease': 'mother'}, 'social_history': {'smoking': '10 pack-years', 'EtOH': 'social'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd']}
# {'json': {'patient_id': 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'date': '2023-02-22', 'age': 56, 'sex': 'female', 'symptoms': ['fever', 'cough', 'fatigue'], 'diagnoses': ['pneumonia', 'type 2 diabetes'], 'medications': ['amoxicillin', 'metformin'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 72, 'temperature': 38.1, 'respiratory_rate': 18}, 'lab_results': {'glucose': 140, 'hemoglobin_A1C': 7.2, 'white_blood_cell_count': 10500}, 'allergies': ['penicillin', 'sulfur drugs'], 'family_history': {'diabetes': 'mother', 'heart_disease': 'father'}, 'social_history': {'smoking_status': 'former', 'packs_per_day': 1.5, 'years_smoked': 10}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd']}
# exception list index out of range
# {'json': {'patient_id': 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'date': '2023-02-28', 'age': 42, 'sex': 'Male', 'symptoms': ['chest_pain', 'shortness_of_breath', 'left_arm_pain'], 'diagnoses': ['acute_myocardial_infarction', 'hypertension'], 'medications': ['aspirin', 'metoprolol', 'lisinopril'], 'vital_signs': {'blood_pressure': '140/90 mmHg', 'heart_rate': '88 bpm', 'respiratory_rate': '18 rpm', 'temperature': '37.1 C', 'oxygen_saturation': '95%'}, 'lab_results': {'cbc': {'wbc': '9,000 cells/mL', 'rbc': '4.5 million cells/mL', 'hemoglobin': '14 g/dL', 'hematocrit': '42%'}, 'basic_metabolic_panel': {'glucose': '110 mg/dL', 'bun': '12 mg/dL', 'creatinine': '1.0 mg/dL', 'sodium': '138 mEq/L', 'potassium': '4.0 mEq/L', 'chloride': '105 mEq/L', 'carbon_dioxide': '24 mEq/L', 'calcium': '9.5 mg/dL'}, 'cardiac_enzymes': {'ck_mb': '180 ng/mL', 'troponin': '2.5 ng/mL'}}, 'allergies': ['penicillin', 'bee_stings'], 'family_history': {'diabetes': 'Mother', 'heart_disease': 'Father'}, 'social_history': {'smoking_status': 'Former', 'packs_per_day': '1', 'years_smoked': '5', 'alcohol_use': 'Moderate'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669']}
# exception list index out of range
# {'json': {'patient_id': 'f54d3e4e-8355-47d0-a509-38df4f456f57', 'date': '2023-02-22', 'age': 47, 'sex': 'male', 'symptoms': ['chest_pain', 'shortness_of_breath', 'fatigue'], 'diagnoses': [{'diagnosis': 'hypertension', 'date': '2020-01-05'}, {'diagnosis': 'coronary_artery_disease', 'date': '2022-11-15'}], 'medications': [{'medication': 'lisinopril', 'dose': '10 mg daily', 'start_date': '2020-01-05'}, {'medication': 'atorvastatin', 'dose': '40 mg daily', 'start_date': '2022-11-15'}], 'vital_signs': {'blood_pressure': '142/88 mmHg', 'heart_rate': 78, 'temperature': 98.6, 'respiratory_rate': 14}, 'lab_results': {'cholesterol': {'total': 225, 'LDL': 150, 'HDL': 40, 'triglycerides': 150}, 'AST': 25, 'ALT': 30, 'creatinine': 1.1}, 'allergies': ['penicillin'], 'family_history': {'diabetes': ['mother'], 'heart_disease': ['father']}, 'social_history': {'smoking_status': 'former smoker', 'packs_per_day': 1, 'years_smoked': 10, 'alcohol_use': 'occasional'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57']}
# exception list index out of range
# {'json': {'patient_id': 'f54d3e4e-8355-47d0-a509-38df4f456f57', 'date': '2023-02-28', 'age': 42, 'sex': 'F', 'symptoms': ['cough', 'fever', 'fatigue'], 'diagnoses': ['viral upper respiratory infection', 'hypertension'], 'medications': ['amlodipine 5mg daily', 'ibuprofen 400mg every 4-6 hours as needed'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 82, 'temperature': 98.6, 'respiratory_rate': 14}, 'lab_results': {'wbc': 6700, 'rbc': 4.5, 'hgb': 12.3, 'hct': 38.1, 'platelets': 255}, 'allergies': ['penicillin', 'shellfish'], 'family_history': ['diabetes', 'breast cancer'], 'social_history': ['smoker', 'occasional alcohol']}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57']}
# exception Expecting ',' delimiter: line 10 column 26 (char 291)
# exception Expecting ',' delimiter: line 10 column 26 (char 340)
# exception Expecting ',' delimiter: line 10 column 26 (char 297)
# exception Expecting ',' delimiter: line 10 column 26 (char 306)
# exception Expecting ',' delimiter: line 17 column 21 (char 456)
# exception Expecting ',' delimiter: line 10 column 26 (char 335)
# {'json': {'patient_id': '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', 'date': '2023-02-27', 'age': 42, 'sex': 'male', 'symptoms': ['cough', 'fever', 'fatigue'], 'diagnoses': ['pneumonia', 'hypertension'], 'medications': ['amoxicillin', 'lisinopril'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 72, 'respiratory_rate': 16, 'temperature': 98.6, 'weight': 182, 'height': 70}, 'lab_results': {'wbc': 9000, 'hgb': 14.2, 'creatinine': 1.1}, 'allergies': ['penicillin', 'cats'], 'family_history': {'diabetes': 'father', 'cancer': 'mother'}, 'social_history': {'smoking': '20 pack-years', 'alcohol': 'social drinker'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57', '8b2fe9b2-7c14-400d-b822-b87d17b1c07d', 'fbbeac88-0412-48b7-b6f3-8bfdb29bba4e', '19047d54-d9c4-4961-a619-6f1f25ac8483', '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000']}
# {'json': {'patient_id': 'ea3cb7c0-934b-486b-abcd-57001064c451', 'date': '2023-02-22', 'age': 52, 'sex': 'male', 'symptoms': ['chest_pain', 'shortness_of_breath', 'nausea'], 'diagnoses': ['acute_myocardial_infarction', 'hypertension'], 'medications': ['aspirin', 'metoprolol', 'lisinopril'], 'vital_signs': {'blood_pressure': '140/90 mmHg', 'heart_rate': '88 bpm', 'respiratory_rate': '18 rpm', 'temperature': '37.1 C', 'oxygen_saturation': '95%'}, 'lab_results': {'hemoglobin': '12.3 g/dL', 'hematocrit': '38%', 'sodium': '138 mmol/L', 'potassium': '4.2 mmol/L', 'creatinine': '1.1 mg/dL'}, 'allergies': ['penicillin', 'shellfish'], 'family_history': {'diabetes': 'mother', 'heart_disease': 'father'}, 'social_history': {'smoking': '20 pack-years', 'alcohol': 'occasional'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57', '8b2fe9b2-7c14-400d-b822-b87d17b1c07d', 'fbbeac88-0412-48b7-b6f3-8bfdb29bba4e', '19047d54-d9c4-4961-a619-6f1f25ac8483', '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', 'ea3cb7c0-934b-486b-abcd-57001064c451']}
# {'json': {'patient_id': '5380d86f-af75-49f2-9514-f9e1e7f9efc5', 'date': '2023-02-15', 'age': 42, 'sex': 'female', 'symptoms': ['chest_pain', 'shortness_of_breath', 'nausea'], 'diagnoses': ['acute_myocardial_infarction', 'hypertension'], 'medications': ['aspirin', 'metoprolol', 'lisinopril'], 'vital_signs': {'blood_pressure': '130/86 mmHg', 'heart_rate': 88, 'respiratory_rate': 18, 'temperature': 98.6, 'oxygen_saturation': 97}, 'lab_results': {'cbc': {'wbc': 9.8, 'rbc': 4.7, 'hemoglobin': 12.3, 'hematocrit': 38.1}, 'cmp': {'sodium': 138, 'potassium': 4.2, 'chloride': 105, 'bicarbonate': 22, 'bun': 12, 'creatinine': 1.0, 'glucose': 110}, 'cardiac_enzymes': {'ckmb': 8.4, 'troponin': 1.5}}, 'allergies': ['penicillin', 'shellfish'], 'family_history': {'diabetes': True, 'cancer': False}, 'social_history': {'smoking': '20_pack_years', 'etoh': 'social'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57', '8b2fe9b2-7c14-400d-b822-b87d17b1c07d', 'fbbeac88-0412-48b7-b6f3-8bfdb29bba4e', '19047d54-d9c4-4961-a619-6f1f25ac8483', '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', 'ea3cb7c0-934b-486b-abcd-57001064c451', '5380d86f-af75-49f2-9514-f9e1e7f9efc5']}
# exception Expecting ',' delimiter: line 10 column 26 (char 340)
# exception Expecting ',' delimiter: line 10 column 26 (char 293)
# exception Expecting ',' delimiter: line 10 column 26 (char 337)
# {'json': {'patient_id': '12205770-fd4a-4284-9d95-da6f186e8764', 'date': '2023-02-15', 'age': 35, 'sex': 'male', 'symptoms': ['chest_pain', 'shortness_of_breath', 'left_arm_pain'], 'diagnoses': ['acute_myocardial_infarction', 'hypertension'], 'medications': ['aspirin', 'metoprolol', 'lisinopril'], 'vital_signs': {'blood_pressure': '130/86 mmHg', 'heart_rate': '88 bpm', 'temperature': '37.2 C', 'respiratory_rate': '18 rpm', 'oxygen_saturation': '95%'}, 'lab_results': {'cbc': {'wbc': '8.4 x10^9/L', 'rbc': '4.5 x10^12/L', 'hemoglobin': '13.2 g/dL', 'hematocrit': '38.1%'}, 'basic_metabolic_panel': {'sodium': '138 mmol/L', 'potassium': '4.2 mmol/L', 'chloride': '105 mmol/L', 'bicarbonate': '22 mmol/L', 'blood_urea_nitrogen': '12 mg/dL', 'creatinine': '1.0 mg/dL', 'glucose': '110 mg/dL'}, 'cardiac_enzymes': {'troponin': '1.2 ng/mL', 'ck_mb': '25 ng/mL'}}, 'allergies': ['penicillin', 'bee_stings'], 'family_history': {'hypertension': True, 'diabetes': False, 'heart_disease': True}, 'social_history': {'smoking': 'former smoker, quit 10 years ago', 'alcohol': 'social drinker', 'occupation': 'accountant'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57', '8b2fe9b2-7c14-400d-b822-b87d17b1c07d', 'fbbeac88-0412-48b7-b6f3-8bfdb29bba4e', '19047d54-d9c4-4961-a619-6f1f25ac8483', '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', 'ea3cb7c0-934b-486b-abcd-57001064c451', '5380d86f-af75-49f2-9514-f9e1e7f9efc5', '3d346427-fc87-4b7d-b54a-dd244ceee919', 'b362d26a-fa19-44ab-9df9-acdfc66bb407', '12205770-fd4a-4284-9d95-da6f186e8764']}
# {'json': {'patient_id': 'b362d26a-fa19-44ab-9df9-acdfc66bb407', 'date': '2021-03-15', 'age': 42, 'sex': 'male', 'symptoms': ['cough', 'fever', 'fatigue'], 'diagnoses': ['pneumonia', 'hypertension'], 'medications': ['amoxicillin', 'lisinopril'], 'vital_signs': {'blood_pressure': '130/85 mmHg', 'heart_rate': 78, 'temperature': 100.1, 'respiratory_rate': 18}, 'lab_results': {'wbc': 9000, 'hgb': 14.2, 'plt': 250}, 'allergies': ['penicillin', 'shellfish'], 'family_history': {'diabetes': True, 'cancer': False}, 'social_history': {'smoking': '20 pack-years', 'alcohol': 'social drinker'}}, 'seen_ids': ['ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'f592839c-2a37-4233-9de0-7486829764e4', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'f54d3e4e-8355-47d0-a509-38df4f456f57', '8b2fe9b2-7c14-400d-b822-b87d17b1c07d', 'fbbeac88-0412-48b7-b6f3-8bfdb29bba4e', '19047d54-d9c4-4961-a619-6f1f25ac8483', '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', 'ea3cb7c0-934b-486b-abcd-57001064c451', '5380d86f-af75-49f2-9514-f9e1e7f9efc5', '3d346427-fc87-4b7d-b54a-dd244ceee919', 'b362d26a-fa19-44ab-9df9-acdfc66bb407', '12205770-fd4a-4284-9d95-da6f186e8764']}
# [{'patient_id': 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'date': '2023-02-22', 'age': 35, 'sex': 'male', 'symptoms': ['cough', 'fever', 'fatigue'], 'diagnoses': ['pneumonia', 'hypertension'], 'medications': ['amoxicillin 500mg', 'lisinopril 10mg'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 80, 'temperature': 100.5, 'respiratory_rate': 18}, 'lab_results': {'wbc': 9000, 'hemoglobin': 14.2, 'platelets': 250}, 'allergies': ['penicillin', 'shellfish'], 'family_history': {'diabetes': 'father', 'heart_disease': 'mother'}, 'social_history': {'smoking': '10 pack-years', 'EtOH': 'social'}}, {'patient_id': 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd', 'date': '2023-02-22', 'age': 56, 'sex': 'female', 'symptoms': ['fever', 'cough', 'fatigue'], 'diagnoses': ['pneumonia', 'type 2 diabetes'], 'medications': ['amoxicillin', 'metformin'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 72, 'temperature': 38.1, 'respiratory_rate': 18}, 'lab_results': {'glucose': 140, 'hemoglobin_A1C': 7.2, 'white_blood_cell_count': 10500}, 'allergies': ['penicillin', 'sulfur drugs'], 'family_history': {'diabetes': 'mother', 'heart_disease': 'father'}, 'social_history': {'smoking_status': 'former', 'packs_per_day': 1.5, 'years_smoked': 10}}, {'patient_id': 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'date': '2023-02-28', 'age': 42, 'sex': 'Male', 'symptoms': ['chest_pain', 'shortness_of_breath', 'left_arm_pain'], 'diagnoses': ['acute_myocardial_infarction', 'hypertension'], 'medications': ['aspirin', 'metoprolol', 'lisinopril'], 'vital_signs': {'blood_pressure': '140/90 mmHg', 'heart_rate': '88 bpm', 'respiratory_rate': '18 rpm', 'temperature': '37.1 C', 'oxygen_saturation': '95%'}, 'lab_results': {'cbc': {'wbc': '9,000 cells/mL', 'rbc': '4.5 million cells/mL', 'hemoglobin': '14 g/dL', 'hematocrit': '42%'}, 'basic_metabolic_panel': {'glucose': '110 mg/dL', 'bun': '12 mg/dL', 'creatinine': '1.0 mg/dL', 'sodium': '138 mEq/L', 'potassium': '4.0 mEq/L', 'chloride': '105 mEq/L', 'carbon_dioxide': '24 mEq/L', 'calcium': '9.5 mg/dL'}, 'cardiac_enzymes': {'ck_mb': '180 ng/mL', 'troponin': '2.5 ng/mL'}}, 'allergies': ['penicillin', 'bee_stings'], 'family_history': {'diabetes': 'Mother', 'heart_disease': 'Father'}, 'social_history': {'smoking_status': 'Former', 'packs_per_day': '1', 'years_smoked': '5', 'alcohol_use': 'Moderate'}}, {'patient_id': 'f54d3e4e-8355-47d0-a509-38df4f456f57', 'date': '2023-02-22', 'age': 47, 'sex': 'male', 'symptoms': ['chest_pain', 'shortness_of_breath', 'fatigue'], 'diagnoses': [{'diagnosis': 'hypertension', 'date': '2020-01-05'}, {'diagnosis': 'coronary_artery_disease', 'date': '2022-11-15'}], 'medications': [{'medication': 'lisinopril', 'dose': '10 mg daily', 'start_date': '2020-01-05'}, {'medication': 'atorvastatin', 'dose': '40 mg daily', 'start_date': '2022-11-15'}], 'vital_signs': {'blood_pressure': '142/88 mmHg', 'heart_rate': 78, 'temperature': 98.6, 'respiratory_rate': 14}, 'lab_results': {'cholesterol': {'total': 225, 'LDL': 150, 'HDL': 40, 'triglycerides': 150}, 'AST': 25, 'ALT': 30, 'creatinine': 1.1}, 'allergies': ['penicillin'], 'family_history': {'diabetes': ['mother'], 'heart_disease': ['father']}, 'social_history': {'smoking_status': 'former smoker', 'packs_per_day': 1, 'years_smoked': 10, 'alcohol_use': 'occasional'}}, {'patient_id': 'f54d3e4e-8355-47d0-a509-38df4f456f57', 'date': '2023-02-28', 'age': 42, 'sex': 'F', 'symptoms': ['cough', 'fever', 'fatigue'], 'diagnoses': ['viral upper respiratory infection', 'hypertension'], 'medications': ['amlodipine 5mg daily', 'ibuprofen 400mg every 4-6 hours as needed'], 'vital_signs': {'blood_pressure': '120/80 mmHg', 'pulse': 82, 'temperature': 98.6, 'respiratory_rate': 14}, 'lab_results': {'wbc': 6700, 'rbc': 4.5, 'hgb': 12.3, 'hct': 38.1, 'platelets': 255}, 'allergies': ['penicillin', 'shellfish'], 'family_history': ['diabetes', 'breast cancer'], 'social_history': ['smoker', 'occasional alcohol']}, {'patient_id': '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', 'date': '2023-0 ...

# %%
loop_and_insert(records, WEAVIATE_URL, "Patient")

# %%
unique_patient_ids = get_unique_patientIDs(WEAVIATE_URL)
print(unique_patient_ids)
# Out:
# [{'patientID': 'ba9df83a-6425-4db2-94b2-ecf0166fdf80'}, {'patientID': '0126a785-cd8d-4d9a-ac3b-39bc7604169a'}, {'patientID': '89ce32d2-fa63-4779-b13a-0f5bf5601016'}, {'patientID': '7a516a15-0126-4464-8b01-21d73f24afd0'}, {'patientID': '5380d86f-af75-49f2-9514-f9e1e7f9efc5'}, {'patientID': 'aa6e43ba-aae6-4938-9d35-67d182592735'}, {'patientID': 'aebdd72f-614e-4053-9715-8789218ce674'}, {'patientID': 'f54d3e4e-8355-47d0-a509-38df4f456f57'}, {'patientID': 'be5466eb-c8d8-43fb-a2d0-904d50f78669'}, {'patientID': '0126a785-cd8d-4d9a-ac3b-39bc7604169a'}, {'patientID': 'ce22bab5-199f-434d-acbc-c6cec7e75d7c'}, {'patientID': 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd'}, {'patientID': 'b362d26a-fa19-44ab-9df9-acdfc66bb407'}, {'patientID': 'e78632e8-ff76-4aa2-8730-a2dadf37d809'}, {'patientID': 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd'}, {'patientID': 'f54d3e4e-8355-47d0-a509-38df4f456f57'}, {'patientID': 'ea3cb7c0-934b-486b-abcd-57001064c451'}, {'patientID': '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000'}, {'patientID': '12205770-fd4a-4284-9d95-da6f186e8764'}, {'patientID': '792e5875-e5a8-4b31-a12a-d1dd86e56206'}]
# ['b362d26a-fa19-44ab-9df9-acdfc66bb407', '9bdc33d6-455c-4aa5-8bf3-7f59d3e9e000', '792e5875-e5a8-4b31-a12a-d1dd86e56206', 'ce22bab5-199f-434d-acbc-c6cec7e75d7c', 'ea3cb7c0-934b-486b-abcd-57001064c451', '7a516a15-0126-4464-8b01-21d73f24afd0', '89ce32d2-fa63-4779-b13a-0f5bf5601016', '0126a785-cd8d-4d9a-ac3b-39bc7604169a', 'ba9df83a-6425-4db2-94b2-ecf0166fdf80', 'be5466eb-c8d8-43fb-a2d0-904d50f78669', 'e78632e8-ff76-4aa2-8730-a2dadf37d809', 'ba78a529-4b96-4aec-b8bc-4d3424cb52cd', '5380d86f-af75-49f2-9514-f9e1e7f9efc5', 'f54d3e4e-8355-47d0-a509-38df4f456f57', 'aebdd72f-614e-4053-9715-8789218ce674', '12205770-fd4a-4284-9d95-da6f186e8764', 'aa6e43ba-aae6-4938-9d35-67d182592735']

# %%
create_summary_database(WEAVIATE_URL, "SummaryTable", unique_patient_ids, model=model)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# /var/folders/sz/88ypmmqn0jq157npq4hmjtkh0000gp/T/ipykernel_95087/2576509624.py:263: DeprecationWarning: invalid escape sequence '\['
#   """You will be provided with a list of diagnoses and medications of patients
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> create_summary_database(WEAVIATE_URL, "SummaryTable", unique_patient_ids, model=model)
#
# /Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb Cell 6 line 1
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=140'>141</a> prompt = ChatPromptTemplate.from_messages(
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=141'>142</a>     [
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=142'>143</a>         (
#    (...)
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=153'>154</a>     ]
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=154'>155</a> )
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=155'>156</a> chain = prompt | model
# --> <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=156'>157</a> summary = chain.invoke({"record_string": id_string}).content
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=158'>159</a> # Vectorize summary
#     <a href='vscode-notebook-cell:/Users/henrywrightson/Projects/Anthropic_hackathon/claude_api.ipynb#X16sZmlsZQ%3D%3D?line=159'>160</a> model = SentenceTransformer("all-MiniLM-L6-v2")
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/langchain/schema/runnable/base.py:1202, in RunnableSequence.invoke(self, input, config)
#    1200 try:
#    1201     for i, step in enumerate(self.steps):
# -> 1202         input = step.invoke(
#    1203             input,
#    1204             # mark each step as a child run
#    1205             patch_config(
#    1206                 config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#    1207             ),
#    1208         )
#    1209 # finish the root run
#    1210 except BaseException as e:
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/langchain/schema/runnable/base.py:2283, in RunnableLambda.invoke(self, input, config, **kwargs)
#    2281 """Invoke this runnable synchronously."""
#    2282 if hasattr(self, "func"):
# -> 2283     return self._call_with_config(
#    2284         self._invoke,
#    2285         input,
#    2286         self._config(config, self.func),
#    2287     )
#    2288 else:
#    2289     raise TypeError(
#    2290         "Cannot invoke a coroutine function synchronously."
#    2291         "Use `ainvoke` instead."
#    2292     )
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/langchain/schema/runnable/base.py:704, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#     697 run_manager = callback_manager.on_chain_start(
#     698     dumpd(self),
#     699     input,
#     700     run_type=run_type,
#     701     name=config.get("run_name"),
#     702 )
#     703 try:
# --> 704     output = call_func_with_variable_args(
#     705         func, input, config, run_manager, **kwargs
#     706     )
#     707 except BaseException as e:
#     708     run_manager.on_chain_error(e)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/langchain/schema/runnable/config.py:308, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     306 if run_manager is not None and accepts_run_manager(func):
#     307     kwargs["run_manager"] = run_manager
# --> 308 return func(input, **kwargs)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/langchain/schema/runnable/base.py:2216, in RunnableLambda._invoke(self, input, run_manager, config)
#    2210 def _invoke(
#    2211     self,
#    2212     input: Input,
#    2213     run_manager: CallbackManagerForChainRun,
#    2214     config: RunnableConfig,
#    2215 ) -> Output:
# -> 2216     output = call_func_with_variable_args(self.func, input, config, run_manager)
#    2217     # If the output is a runnable, invoke it
#    2218     if isinstance(output, Runnable):
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/langchain/schema/runnable/config.py:308, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     306 if run_manager is not None and accepts_run_manager(func):
#     307     kwargs["run_manager"] = run_manager
# --> 308 return func(input, **kwargs)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/torch/nn/modules/container.py:215, in Sequential.forward(self, input)
#     213 def forward(self, input):
#     214     for module in self:
# --> 215         input = module(input)
#     216     return input
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/.pyenv/versions/3.11.4/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:62, in Transformer.forward(self, features)
#      60 def forward(self, features):
#      61     """Returns token_embeddings, cls_token"""
# ---> 62     trans_features = {'input_ids': features['input_ids'], 'attention_mask': features['attention_mask']}
#      63     if 'token_type_ids' in features:
#      64         trans_features['token_type_ids'] = features['token_type_ids']
#
# TypeError: 'ChatPromptValue' object is not subscriptable

# %%
filtered_pids, summary = filter_for_symptoms("patientID", "symptoms", WEAVIATE_URL, 10, "Patient", "SummaryTable")
print(filtered_pids)
print(summary)

# %%
# This is presented to the Dr / In app
final_diagnoses_and_medication = get_final_output(filtered_pids)
print(final_diagnoses_and_medication)

# %%
# This is presented to the patient
pesonalised_summary = create_natural_language_summary(summary, final_diagnoses_and_medication, "layman")

# %%
properties = ["symptoms, diagnoses"]

results = client.query.get("Patient", properties).do()

print(json.dumps(results, indent=2))
# Out:
# {
#   "data": {
#     "Get": {
#       "Patient": [
#         {
#           "diagnoses": [
#             "hypertension",
#             "diabetes_mellitus_type_2"
#           ],
#           "symptoms": [
#             "chest_pain",
#             "shortness_of_breath",
#             "nausea"
#           ]
#         },
#         {
#           "diagnoses": [
#             "hypertension",
#             "coronary_artery_disease"
#           ],
#           "symptoms": [
#             "chest_pain",
#             "shortness_of_breath",
#             "fatigue"
#           ]
#         },
#         {
#           "diagnoses": [
#             "acute_myocardial_infarction",
#             "hypertension"
#           ],
#           "symptoms": [
#             "chest_pain",
#             "shortness_of_breath",
#             "nausea"
#           ]
#         }
#       ]
#     }
#   }
# }

# %%
import weaviate
import os

auth_config = weaviate.AuthApiKey(api_key="kbypW858drjOi8i6fSTB4cNJb2FboJHVdMp3")
client = weaviate.Client(url="https://diagnosis-ai-generator-kk6m9y1x.weaviate.network", auth_client_secret=auth_config)  

client.schema.get()
# Out:
# {'classes': [{'class': 'SummaryTable',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['uuid'],
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'name': 'patientID'}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'none'},
#   {'class': 'Patient',
#    'description': 'Patient medical record',
#    'invertedIndexConfig': {'bm25': {'b': 0.75, 'k1': 1.2},
#     'cleanupIntervalSeconds': 60,
#     'stopwords': {'additions': None, 'preset': 'en', 'removals': None}},
#    'moduleConfig': {'text2vec-openai': {'baseURL': 'https://api.openai.com',
#      'model': 'ada',
#      'modelVersion': '002',
#      'type': 'text',
#      'vectorizeClassName': True}},
#    'multiTenancyConfig': {'enabled': False},
#    'properties': [{'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'sex',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'symptoms',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'medications',
#      'tokenization': 'word'},
#     {'dataType': ['text[]'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'allergies',
#      'tokenization': 'word'},
#     {'dataType': ['object'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'social_history',
#      'nestedProperties': [{'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'alcohol_use',
#        'tokenization': 'word'},
#       {'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'smoking_status',
#        'tokenization': 'word'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'drinks_per_week'},
#       {'dataType': ['boolean'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'drug_use'},
#       {'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'drinking_status',
#        'tokenization': 'word'},
#       {'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'smoking',
#        'tokenization': 'word'},
#       {'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'alcohol',
#        'tokenization': 'word'},
#       {'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'exercise',
#        'tokenization': 'word'}]},
#     {'dataType': ['object'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'family_history',
#      'nestedProperties': [{'dataType': ['boolean'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'diabetes'},
#       {'dataType': ['boolean'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'cancer'},
#       {'dataType': ['text[]'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'heart_disease',
#        'tokenization': 'word'}]},
#     {'dataType': ['uuid'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'patient_id'},
#     {'dataType': ['text'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'date',
#      'tokenization': 'word'},
#     {'dataType': ['number'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'age'},
#     {'dataType': ['text[]'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': True,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'diagnoses',
#      'tokenization': 'word'},
#     {'dataType': ['object'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'vital_signs',
#      'nestedProperties': [{'dataType': ['text'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': True,
#        'name': 'blood_pressure',
#        'tokenization': 'word'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'heart_rate'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'respiratory_rate'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'temperature'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'weight'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'height'}]},
#     {'dataType': ['object'],
#      'description': "This property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#      'indexFilterable': True,
#      'indexSearchable': False,
#      'moduleConfig': {'text2vec-openai': {'skip': False,
#        'vectorizePropertyName': False}},
#      'name': 'lab_results',
#      'nestedProperties': [{'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'glucose'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'creatinine'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'cholesterol'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'hemoglobin'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'hematocrit'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'iron'},
#       {'dataType': ['object'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'cbc',
#        'nestedProperties': [{'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'hgb'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'hct'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'platelets'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'wbc'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'rbc'}]},
#       {'dataType': ['object'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'cmp',
#        'nestedProperties': [{'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'cl'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'co2'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'bun'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'creatinine'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'glucose'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'na'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:54:26 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'k'}]},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'wbc'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'sodium'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'potassium'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'alt'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'rbc'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'hgb'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'hct'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'platelets'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'ast'},
#       {'dataType': ['number'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'crp'},
#       {'dataType': ['object'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'hematology',
#        'nestedProperties': [{'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'wbc'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'rbc'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'hgb'}]},
#       {'dataType': ['object'],
#        'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#        'indexFilterable': True,
#        'indexSearchable': False,
#        'name': 'chemistry',
#        'nestedProperties': [{'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'glucose'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'na'},
#         {'dataType': ['number'],
#          'description': "This nested property was generated by Weaviate's auto-schema feature on Sun Nov  5 09:56:19 2023",
#          'indexFilterable': True,
#          'indexSearchable': False,
#          'name': 'k'}]}]}],
#    'replicationConfig': {'factor': 1},
#    'shardingConfig': {'virtualPerPhysical': 128,
#     'desiredCount': 1,
#     'actualCount': 1,
#     'desiredVirtualCount': 128,
#     'actualVirtualCount': 128,
#     'key': '_id',
#     'strategy': 'hash',
#     'function': 'murmur3'},
#    'vectorIndexConfig': {'skip': False,
#     'cleanupIntervalSeconds': 300,
#     'maxConnections': 64,
#     'efConstruction': 128,
#     'ef': -1,
#     'dynamicEfMin': 100,
#     'dynamicEfMax': 500,
#     'dynamicEfFactor': 8,
#     'vectorCacheMaxObjects': 1000000000000,
#     'flatSearchCutoff': 40000,
#     'distance': 'cosine',
#     'pq': {'enabled': False,
#      'bitCompression': False,
#      'segments': 0,
#      'centroids': 256,
#      'trainingLimit': 100000,
#      'encoder': {'type': 'kmeans', 'distribution': 'log-normal'}}},
#    'vectorIndexType': 'hnsw',
#    'vectorizer': 'text2vec-openai'}]}

# %%
cls = {
            "class": "Patient",
            "description": "Patient medical record",
            "properties": [],
        }

client.schema.create_class(cls)

# %%
client.schema.delete_class("Patient")
